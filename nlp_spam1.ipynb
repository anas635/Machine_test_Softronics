# %% [markdown]
# # spam or ham 1

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('/content/drive/MyDrive/ML datasets/Unsupervised and NLP/spam_ham_dataset.csv')
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  Subject: enron methanol ; meter # : 988291\r\n...
# 1           2349   ham  Subject: hpl nom for january 9 , 2001\r\n( see...
# 2           3624   ham  Subject: neon retreat\r\nho ho ho , we ' re ar...
# 3           4685  spam  Subject: photoshop , windows , office . cheap ...
# 4           2030   ham  Subject: re : indian springs\r\nthis deal is t...
# ...          ...   ...                                                ...
# 5166        1518   ham  Subject: put the 10 on the ft\r\nthe transport...
# 5167         404   ham  Subject: 3 / 4 / 2000 and following noms\r\nhp...
# 5168        2933   ham  Subject: calpine daily gas nomination\r\n>\r\n...
# 5169        1409   ham  Subject: industrial worksheets for august 2000...
# 5170        4807  spam  Subject: important online banking alert\r\ndea...
#
#       label_num
# 0             0
# 1             0
# 2             0
# ...

# %%
df.isna().sum(),df.duplicated().sum()
# Out:
# (Unnamed: 0    0
#  label         0
#  text          0
#  label_num     0
#  dtype: int64,
#  0)

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from string import punctuation
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')

stop=stopwords.words('english')
lemma=WordNetLemmatizer()
def preprocess(sent):
  a=word_tokenize(''.join([i for i in sent.lower() if i not in punctuation]))
  return ' '.join(lemma.lemmatize(i,'v') for i in a if i not in stop)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
tekst="I love programming in Python! It's amazing, and I learn new things every day."
preprocess(tekst)
# Out:
# 'love program python amaze learn new things every day'

# %%
df['text']=df['text'].apply(func=preprocess)

# %%
df
# Out:
#       Unnamed: 0 label                                               text  \
# 0            605   ham  subject enron methanol meter 988291 follow not...
# 1           2349   ham  subject hpl nom january 9 2001 see attach file...
# 2           3624   ham  subject neon retreat ho ho ho around wonderful...
# 3           4685  spam  subject photoshop windows office cheap main tr...
# 4           2030   ham  subject indian spring deal book teco pvr reven...
# ...          ...   ...                                                ...
# 5166        1518   ham  subject put 10 ft transport volumes decrease 2...
# 5167         404   ham  subject 3 4 2000 follow noms hpl take extra 15...
# 5168        2933   ham  subject calpine daily gas nomination julie men...
# 5169        1409   ham  subject industrial worksheets august 2000 acti...
# 5170        4807  spam  subject important online bank alert dear value...
#
#       label_num
# 0             0
# 1             0
# 2             0
# ...

# %%
x=df['text']
y=df['label_num']

# %%
df['label_num'].value_counts()
# Out:
# label_num
# 0    3672
# 1    1499
# Name: count, dtype: int64

# %% [markdown]
# count vectoriser

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
vectoriser=CountVectorizer()
vectoriser1=TfidfVectorizer()
x_vector=vectoriser.fit_transform(x)
x_vector1=vectoriser1.fit_transform(x)

# %%
x_vector.shape,x_vector1.shape
# Out:
# ((5171, 46742), (5171, 46742))

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x_vector1,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
models=classification_algorithms = [
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    XGBClassifier(),
    SVC(),
    MultinomialNB(),
    KNeighborsClassifier(),
]

# %%
from sklearn.metrics import accuracy_score,classification_report
for model in models:
  model.fit(xtrain,ytrain)
  ypred=model.predict(xtest)
  print(f'{model}:= \n {classification_report(ytest,ypred)}')
  print('==================================================')
# Out:
# DecisionTreeClassifier():=
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      3000
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
# ...
# RandomForestClassifier():=
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      3000
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000
#
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0bf0f82358a5> in <cell line: 2>()
#       1 from sklearn.metrics import accuracy_score,classification_report
#       2 for model in models:
# ----> 3   model.fit(xtrain,ytrain)
# ...

# %% [markdown]
# Sampling

# %%
from imblearn.over_sampling import RandomOverSampler
sampler=RandomOverSampler()
x_res,y_res=sampler.fit_resample(x_vector1,y)

# %%
y_res.value_counts()
# Out:
# label_num
# 0    3672
# 1    3672
# Name: count, dtype: int64

# %%
xrtrain,xrtest,yrtrain,yrtest=train_test_split(x_res,y_res,test_size=0.3)

# %%
for model in models:
  model.fit(xrtrain,yrtrain)
  yrpred=model.predict(xrtest)
  print(f'{model}:= \n {classification_report(yrtest,yrpred)}')
  print('==================================================')
# Out:
# DecisionTreeClassifier():=
#                precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      1086
#            1       0.96      0.99      0.97      1118
#
#     accuracy                           0.97      2204
#    macro avg       0.97      0.97      0.97      2204
# weighted avg       0.97      0.97      0.97      2204
#
# ...
# RandomForestClassifier():=
#                precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99      1086
#            1       0.98      1.00      0.99      1118
#
#     accuracy                           0.99      2204
#    macro avg       0.99      0.99      0.99      2204
# weighted avg       0.99      0.99      0.99      2204
#
# ...
# GradientBoostingClassifier():=
#                precision    recall  f1-score   support
#
#            0       1.00      0.93      0.96      1086
#            1       0.93      1.00      0.96      1118
#
# ...

# %%
# model1.score(xrtrain,yrtrain)
# model2.score(xrtrain,yrtrain)
# model2.score(xrtest,yrtest)
# Out:
# 0.9975820379965458

# %%
from sklearn.model_selection import cross_val_score
for model in models:
  print(f'{model}\n{cross_val_score(model,x_vector,y)}')
# Out:
# DecisionTreeClassifier()
# [0.95169082 0.94777563 0.94197292 0.94294004 0.92746615]
# RandomForestClassifier()
# [0.9826087  0.97485493 0.97582205 0.96421663 0.96808511]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-87e7374d8107> in <cell line: 2>()
#       1 from sklearn.model_selection import cross_val_score
#       2 for model in models:
# ----> 3   print(f'{model}\n{cross_val_score(model,x_vector,y)}')
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# ...

# %% [markdown]
# SUMMING UP

# %%
mod=RandomForestClassifier()
mod.fit(xrtrain,yrtrain)
# Out:
# RandomForestClassifier()

# %%
def predict():
  a=input('enter the tekst:')
  a=preprocess(a)
  a=vectoriser1.transform([a])
  pred=mod.predict(a)
  if pred[0] == 0:
    return 'No Spam'
  else:
    return 'Spam'

print(predict())
# Out:
# enter the tekst:hello soman
# Spam
